# %%
import json
import pandas as pd
from understatscraper import Understat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/46/473v791s22sd630cw2_wnkrwhrhwgc/T/ipykernel_90371/111183402.py in <module>
#       1 import json
#       2 import pandas as pd
# ----> 3 from understatscraper import Understat
#
# ModuleNotFoundError: No module named 'understatscraper'

# %%
# creating an instance of the class Understat
understat = Understat()

# %%
#calling a function to scrape shots data for the EPL season 20/21
#returns a dataframe containing all the shots data from the EPL season 20/21
# df = understat.season('Serie A', 2021)
# print(df)

# %%
# #calling a function to scrape shots data for Raheem Sterling from the 20/21 EPL season.
# df = understat.season('Serie A', 2022, team='AC milan')
# print(df)

# %%
milan_games = ["17121"
"17091",
"17081",
"17074",
"17061",
"17047",
"17040",
"17032",
"17021",
"17012",
"17001",
"16989",
"16982",
"16970",
"16965",
"16951",
"16936",
"16931",
"16924",
"16910",
"16899",
"16889",
"16878",
"16870",
"16862",
"16850",
"16837",
"16831",
"16816",
"16812",
"16800",
"16790",
"16780",
"16774",
"16765"]

print(len(milan_games))
# Out:
# 34

# %%
# df = understat.single_match(17091)
# print(df)

df = pd.DataFrame()
for e in milan_games[:]:
    this_game = understat.single_match(e)
    this_game['match_id'] = e
    df = df.append(this_game, ignore_index=True)

# print(df)
# Out:
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   home_df = json_normalize(data['h'],sep='_')
# /Users/jinlong/opt/anaconda3/lib/python3.8/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   away_df = json_normalize(data['a'],sep='_')
# /var/folders/yg/229tct093h30f6c9ltbnpsx40000gn/T/ipykernel_4029/981102819.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(this_game, ignore_index=True)

# %%
df.to_csv('data.csv', sep='\t', encoding='utf-8')
